# %%
# !pip install roboflow supervision

# %%
# !pip3 install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\adamz\onedrive\github\resort-pool-management\.conda\lib\site-packages (from opencv-python) (2.1.0)
# Using cached opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.10.0.84

# %%
import os
from roboflow import Roboflow
import numpy as np
import supervision as sv
import cv2
import json

# %% [markdown]
# ## Run Video Inference
#
# Configure Roboflow project, pick the latest deployed model version from Roboflow Universe.
# Call the predict_video method to run inference on the video and get the results:

# %%
PROJECT_NAME = "resort-pool"
#VIDEO_FILE = "https://storage.googleapis.com/bucket-trial-run/test-video.mp4"
VIDEO_FILE = "test-video-2.mp4"
ANNOTATED_VIDEO = "test-output.mp4"
API_KEYS = json.load(open('api_keys.json'))

rf = Roboflow(api_key=API_KEYS['roboflow_key'])
project = rf.workspace().project(PROJECT_NAME)
model = project.version("3").model

job_id, signed_url, expire_time = model.predict_video(
   VIDEO_FILE,
   fps=5,
   prediction_type="batch-video"
)
results = model.poll_until_video_results(job_id)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Checking for video inference results for job 7e36988e-b0d5-4e48-8f47-9211c7e8cc12 every 60s
# (0s): Checking for inference results

# %%
print(results)
# Out:
# {'_id': '7e36988e-b0d5-4e48-8f47-9211c7e8cc12', 'created_at': 'Tue, 27 Aug 2024 02:03:56 GMT', 'crop_area': 'full', 'infer_fps': 5, 'infer_models': [{'api_key': 'DH5gBVYCe2nVf0JTKya0', 'infer_errors': 0, 'infer_success': 0, 'inference_type': 'object-detection', 'model_id': 'resort-pool', 'model_version': 3}], 'memo': 'R4SLXgqZThxdfMr39sXa', 'metadata': '', 'pubsub_message_id': '12066324692305288', 'retries': 1, 'signed_url': 'https://storage.googleapis.com/roboflow_video_inference_input_prod/R4SLXgqZThxdfMr39sXa/test-video-2.mp4?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=roboflow-platform%40appspot.gserviceaccount.com%2F20240827%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20240827T020307Z&X-Goog-Expires=86400&X-Goog-SignedHeaders=content-type%3Bhost&X-Goog-Signature=...', 'status': 2, 'status_info': 'object-detection error', 'updated_at': 'Tue, 27 Aug 2024 02:04:12 GMT', 'webhook_url': ''}

# %% [markdown]
# ## Apply Custom Annotations
# To enhance the quality of our annotations, we can utilize custom annotators from the 'supervision' package.
# In this example, we use 'BoxAnnotator' and 'LabelAnnotator' to improve our annotations:

# %%
box_mask_annotator = sv.BoxAnnotator()
label_annotator = sv.LabelAnnotator()
tracker = sv.ByteTrack()
# box_annotator = sv.BoundingBoxAnnotator()
# halo_annotator = sv.HaloAnnotator()
# corner_annotator = sv.BoxCornerAnnotator()
# circle_annotator = sv.CircleAnnotator()
# blur_annotator = sv.BlurAnnotator()
# heat_map_annotator = sv.HeatMapAnnotator()

# %% [markdown]
# ## Annotate Frames
# To annotate frames in the video, we'll define a function called `annotate_frame` that utilizes the obtained results from video inference.
#
# Then for each frame, we:
#
# Get the detection data from Roboflow's results
# Create annotations with Supervision for that frame
# Overlay annotations on the frame

# %%
cap = cv2.VideoCapture(VIDEO_FILE)
frame_rate = cap.get(cv2.CAP_PROP_FPS)
cap.release()

def annotate_frame(frame: np.ndarray, frame_number: int) -> np.ndarray:
    try:
        time_offset = frame_number / frame_rate
        closest_time_offset = min(results['time_offset'], key=lambda t: abs(t - time_offset))
        index = results['time_offset'].index(closest_time_offset)
        detection_data = results[PROJECT_NAME][index]

        roboflow_format = {
            "predictions": detection_data['predictions'],
            "image": {"width": frame.shape[1], "height": frame.shape[0]}
        }
        detections = sv.Detections.from_inference(roboflow_format)
        detections = tracker.update_with_detections(detections)
        labels = [pred['class'] for pred in detection_data['predictions']]

    except (IndexError, KeyError, ValueError) as e:
        print(f"Exception in processing frame {frame_number}: {e}")
        detections = sv.Detections(xyxy=np.empty((0, 4)),
                                   confidence=np.empty(0),
                                   class_id=np.empty(0, dtype=int))
        labels = []

    annotated_frame = box_mask_annotator.annotate(frame.copy(), detections=detections)
    annotated_frame = label_annotator.annotate(annotated_frame, detections=detections, labels=labels)
    return annotated_frame

# %% [markdown]
# ## Write Output Video
#
# Finally, we annotate the full video:

# %%
sv.process_video(
   source_path=VIDEO_FILE,
   target_path=ANNOTATED_VIDEO,
   callback=annotate_frame
)
# Out:
# Exception in processing frame 0: 'time_offset'
# Exception in processing frame 1: 'time_offset'
# Exception in processing frame 2: 'time_offset'
# Exception in processing frame 3: 'time_offset'
# Exception in processing frame 4: 'time_offset'
# Exception in processing frame 5: 'time_offset'
# Exception in processing frame 6: 'time_offset'
# Exception in processing frame 7: 'time_offset'
# Exception in processing frame 8: 'time_offset'
# Exception in processing frame 9: 'time_offset'
# Exception in processing frame 10: 'time_offset'
# Exception in processing frame 11: 'time_offset'
# Exception in processing frame 12: 'time_offset'
# Exception in processing frame 13: 'time_offset'
# Exception in processing frame 14: 'time_offset'
# Exception in processing frame 15: 'time_offset'
# Exception in processing frame 16: 'time_offset'
# Exception in processing frame 17: 'time_offset'
# Exception in processing frame 18: 'time_offset'
# Exception in processing frame 19: 'time_offset'
# Exception in processing frame 20: 'time_offset'
# Exception in processing frame 21: 'time_offset'
# Exception in processing frame 22: 'time_offset'
# Exception in processing frame 23: 'time_offset'
# Exception in processing frame 24: 'time_offset'
# Exception in processing frame 25: 'time_offset'
# Exception in processing frame 26: 'time_offset'
# Exception in processing frame 27: 'time_offset'
# Exception in processing frame 28: 'time_offset'
# Exception in processing frame 29: 'time_offset'
# Exception in processing frame 30: 'time_offset'
# Exception in processing frame 31: 'time_offset'
# Exception in processing frame 32: 'time_offset'
# Exception in processing frame 33: 'time_offset'
# Exception in processing frame 34: 'time_offset'
# Exception in processing frame 35: 'time_offset'
# Exception in processing frame 36: 'time_offset'
# Exception in processing frame 37: 'time_offset'
# Exception in processing frame 38: 'time_offset'
# Exception in processing frame 39: 'time_offset'
# Exception in processing frame 40: 'time_offset'
# Exception in processing frame 41: 'time_offset'
# Exception in processing frame 42: 'time_offset'
# Exception in processing frame 43: 'time_offset'
# Exception in processing frame 44: 'time_offset'
# Exception in processing frame 45: 'time_offset'
# Exception in processing frame 46: 'time_offset'
# Exception in processing frame 47: 'time_offset'
# Exception in processing frame 48: 'time_offset'
# Exception in processing frame 49: 'time_offset'
# Exception in processing frame 50: 'time_offset'
# Exception in processing frame 51: 'time_offset'
# Exception in processing frame 52: 'time_offset'
# Exception in processing frame 53: 'time_offset'
# Exception in processing frame 54: 'time_offset'
# Exception in processing frame 55: 'time_offset'
# Exception in processing frame 56: 'time_offset'
# Exception in processing frame 57: 'time_offset'
# Exception in processing frame 58: 'time_offset'
# Exception in processing frame 59: 'time_offset'
# Exception in processing frame 60: 'time_offset'
# Exception in processing frame 61: 'time_offset'
# Exception in processing frame 62: 'time_offset'
# Exception in processing frame 63: 'time_offset'
# Exception in processing frame 64: 'time_offset'
# Exception in processing frame 65: 'time_offset'
# Exception in processing frame 66: 'time_offset'
# Exception in processing frame 67: 'time_offset'
# Exception in processing frame 68: 'time_offset'
# Exception in processing frame 69: 'time_offset'
# Exception in processing frame 70: 'time_offset'
# Exception in processing frame 71: 'time_offset'
# Exception in processing frame 72: 'time_offset'
# Exception in processing frame 73: 'time_offset'
# Exception in processing frame 74: 'time_offset'
# Exception in processing frame 75: 'time_offset'
# Exception in processing frame 76: 'time_offset'
# Exception in processing frame 77: 'time_offset'
# Exception in processing frame 78: 'time_offset'
# Exception in processing frame 79: 'time_offset'
# Exception in processing frame 80: 'time_offset'
# Exception in processing frame 81: 'time_offset'
# Exception in processing frame 82: 'time_offset'
# Exception in processing frame 83: 'time_offset'
# Exception in processing frame 84: 'time_offset'
# Exception in processing frame 85: 'time_offset'
# Exception in processing frame 86: 'time_offset'
# Exception in processing frame 87: 'time_offset'
# Exception in processing frame 88: 'time_offset'
# Exception in processing frame 89: 'time_offset'
# Exception in processing frame 90: 'time_offset'
# Exception in processing frame 91: 'time_offset'
# Exception in processing frame 92: 'time_offset'
# Exception in processing frame 93: 'time_offset'
# Exception in processing frame 94: 'time_offset'
# Exception in processing frame 95: 'time_offset'
# Exception in processing frame 96: 'time_offset'
# Exception in processing frame 97: 'time_offset'
# Exception in processing frame 98: 'time_offset'
# Exception in processing frame 99: 'time_offset'
# Exception in processing frame 100: 'time_offset'
# Exception in processing frame 101: 'time_offset'
# Exception in processing frame 102: 'time_offset'
# Exception in processing frame 103: 'time_offset'
# Exception in processing frame 104: 'time_offset'
# Exception in processing frame 105: 'time_offset'
# Exception in processing frame 106: 'time_offset'
# Exception in processing frame 107: 'time_offset'
# Exception in processing frame 108: 'time_offset'
# Exception in processing frame 109: 'time_offset'
# Exception in processing frame 110: 'time_offset'
# Exception in processing frame 111: 'time_offset'
# Exception in processing frame 112: 'time_offset'
# Exception in processing frame 113: 'time_offset'
# Exception in processing frame 114: 'time_offset'
# Exception in processing frame 115: 'time_offset'
# Exception in processing frame 116: 'time_offset'
# Exception in processing frame 117: 'time_offset'
# Exception in processing frame 118: 'time_offset'
# Exception in processing frame 119: 'time_offset'
# Exception in processing frame 120: 'time_offset'
# Exception in processing frame 121: 'time_offset'
# Exception in processing frame 122: 'time_offset'
# Exception in processing frame 123: 'time_offset'
# Exception in processing frame 124: 'time_offset'
# Exception in processing frame 125: 'time_offset'
# Exception in processing frame 126: 'time_offset'
# Exception in processing frame 127: 'time_offset'
# Exception in processing frame 128: 'time_offset'
# Exception in processing frame 129: 'time_offset'
# Exception in processing frame 130: 'time_offset'
# Exception in processing frame 131: 'time_offset'
# Exception in processing frame 132: 'time_offset'
# Exception in processing frame 133: 'time_offset'
# Exception in processing frame 134: 'time_offset'
# Exception in processing frame 135: 'time_offset'
# Exception in processing frame 136: 'time_offset'
# Exception in processing frame 137: 'time_offset'
# Exception in processing frame 138: 'time_offset'
# Exception in processing frame 139: 'time_offset'
# Exception in processing frame 140: 'time_offset'
# Exception in processing frame 141: 'time_offset'
# Exception in processing frame 142: 'time_offset'
# Exception in processing frame 143: 'time_offset'
# Exception in processing frame 144: 'time_offset'
# Exception in processing frame 145: 'time_offset'
# Exception in processing frame 146: 'time_offset'
# Exception in processing frame 147: 'time_offset'
# Exception in processing frame 148: 'time_offset'
# Exception in processing frame 149: 'time_offset'
# Exception in processing frame 150: 'time_offset'
# Exception in processing frame 151: 'time_offset'
# Exception in processing frame 152: 'time_offset'
# Exception in processing frame 153: 'time_offset'
# Exception in processing frame 154: 'time_offset'
# Exception in processing frame 155: 'time_offset'
# Exception in processing frame 156: 'time_offset'
# Exception in processing frame 157: 'time_offset'
# Exception in processing frame 158: 'time_offset'
# Exception in processing frame 159: 'time_offset'
# Exception in processing frame 160: 'time_offset'
# Exception in processing frame 161: 'time_offset'
# Exception in processing frame 162: 'time_offset'
# Exception in processing frame 163: 'time_offset'
# Exception in processing frame 164: 'time_offset'
# Exception in processing frame 165: 'time_offset'
# Exception in processing frame 166: 'time_offset'
# Exception in processing frame 167: 'time_offset'
# Exception in processing frame 168: 'time_offset'
# Exception in processing frame 169: 'time_offset'
# Exception in processing frame 170: 'time_offset'
# Exception in processing frame 171: 'time_offset'
# Exception in processing frame 172: 'time_offset'
# Exception in processing frame 173: 'time_offset'
# Exception in processing frame 174: 'time_offset'
# Exception in processing frame 175: 'time_offset'
# Exception in processing frame 176: 'time_offset'
# Exception in processing frame 177: 'time_offset'
# Exception in processing frame 178: 'time_offset'
# Exception in processing frame 179: 'time_offset'
# Exception in processing frame 180: 'time_offset'
# Exception in processing frame 181: 'time_offset'
# Exception in processing frame 182: 'time_offset'
# Exception in processing frame 183: 'time_offset'
# Exception in processing frame 184: 'time_offset'
# Exception in processing frame 185: 'time_offset'
# Exception in processing frame 186: 'time_offset'
# Exception in processing frame 187: 'time_offset'
# Exception in processing frame 188: 'time_offset'
# Exception in processing frame 189: 'time_offset'
# Exception in processing frame 190: 'time_offset'
# Exception in processing frame 191: 'time_offset'
# Exception in processing frame 192: 'time_offset'
# Exception in processing frame 193: 'time_offset'
# Exception in processing frame 194: 'time_offset'
# Exception in processing frame 195: 'time_offset'
# Exception in processing frame 196: 'time_offset'
# Exception in processing frame 197: 'time_offset'
# Exception in processing frame 198: 'time_offset'
# Exception in processing frame 199: 'time_offset'
# Exception in processing frame 200: 'time_offset'
# Exception in processing frame 201: 'time_offset'
# Exception in processing frame 202: 'time_offset'
# Exception in processing frame 203: 'time_offset'
# Exception in processing frame 204: 'time_offset'
# Exception in processing frame 205: 'time_offset'
# Exception in processing frame 206: 'time_offset'
# Exception in processing frame 207: 'time_offset'
# Exception in processing frame 208: 'time_offset'
# Exception in processing frame 209: 'time_offset'
# Exception in processing frame 210: 'time_offset'
# Exception in processing frame 211: 'time_offset'
# Exception in processing frame 212: 'time_offset'
# Exception in processing frame 213: 'time_offset'
# Exception in processing frame 214: 'time_offset'
# Exception in processing frame 215: 'time_offset'
# Exception in processing frame 216: 'time_offset'
# Exception in processing frame 217: 'time_offset'
# Exception in processing frame 218: 'time_offset'
# Exception in processing frame 219: 'time_offset'
# Exception in processing frame 220: 'time_offset'
# Exception in processing frame 221: 'time_offset'
# Exception in processing frame 222: 'time_offset'
# Exception in processing frame 223: 'time_offset'
# Exception in processing frame 224: 'time_offset'
# Exception in processing frame 225: 'time_offset'
# Exception in processing frame 226: 'time_offset'
# Exception in processing frame 227: 'time_offset'
# Exception in processing frame 228: 'time_offset'
# Exception in processing frame 229: 'time_offset'
# Exception in processing frame 230: 'time_offset'
# Exception in processing frame 231: 'time_offset'
# Exception in processing frame 232: 'time_offset'
# Exception in processing frame 233: 'time_offset'
# Exception in processing frame 234: 'time_offset'
# Exception in processing frame 235: 'time_offset'
# Exception in processing frame 236: 'time_offset'
# Exception in processing frame 237: 'time_offset'
# Exception in processing frame 238: 'time_offset'
# Exception in processing frame 239: 'time_offset'
# Exception in processing frame 240: 'time_offset'
# Exception in processing frame 241: 'time_offset'
# Exception in processing frame 242: 'time_offset'
# Exception in processing frame 243: 'time_offset'
# Exception in processing frame 244: 'time_offset'
# Exception in processing frame 245: 'time_offset'
# Exception in processing frame 246: 'time_offset'
# Exception in processing frame 247: 'time_offset'
# Exception in processing frame 248: 'time_offset'
# Exception in processing frame 249: 'time_offset'
# Exception in processing frame 250: 'time_offset'
# Exception in processing frame 251: 'time_offset'
# Exception in processing frame 252: 'time_offset'
# Exception in processing frame 253: 'time_offset'
# Exception in processing frame 254: 'time_offset'
# Exception in processing frame 255: 'time_offset'
# Exception in processing frame 256: 'time_offset'
# Exception in processing frame 257: 'time_offset'
# Exception in processing frame 258: 'time_offset'
# Exception in processing frame 259: 'time_offset'
# Exception in processing frame 260: 'time_offset'
# Exception in processing frame 261: 'time_offset'
# Exception in processing frame 262: 'time_offset'
# Exception in processing frame 263: 'time_offset'
# Exception in processing frame 264: 'time_offset'
# Exception in processing frame 265: 'time_offset'
# Exception in processing frame 266: 'time_offset'
# Exception in processing frame 267: 'time_offset'
# Exception in processing frame 268: 'time_offset'
# Exception in processing frame 269: 'time_offset'
# Exception in processing frame 270: 'time_offset'
# Exception in processing frame 271: 'time_offset'
# Exception in processing frame 272: 'time_offset'
# Exception in processing frame 273: 'time_offset'
# Exception in processing frame 274: 'time_offset'
# Exception in processing frame 275: 'time_offset'
# Exception in processing frame 276: 'time_offset'
# Exception in processing frame 277: 'time_offset'
# Exception in processing frame 278: 'time_offset'
# Exception in processing frame 279: 'time_offset'
# Exception in processing frame 280: 'time_offset'
# Exception in processing frame 281: 'time_offset'
# Exception in processing frame 282: 'time_offset'
# Exception in processing frame 283: 'time_offset'
# Exception in processing frame 284: 'time_offset'
# Exception in processing frame 285: 'time_offset'
# Exception in processing frame 286: 'time_offset'
# Exception in processing frame 287: 'time_offset'
# Exception in processing frame 288: 'time_offset'
# Exception in processing frame 289: 'time_offset'
# Exception in processing frame 290: 'time_offset'
# Exception in processing frame 291: 'time_offset'
# Exception in processing frame 292: 'time_offset'
# Exception in processing frame 293: 'time_offset'
# Exception in processing frame 294: 'time_offset'
# Exception in processing frame 295: 'time_offset'
# Exception in processing frame 296: 'time_offset'
# Exception in processing frame 297: 'time_offset'
# Exception in processing frame 298: 'time_offset'
# Exception in processing frame 299: 'time_offset'
# Exception in processing frame 300: 'time_offset'
# Exception in processing frame 301: 'time_offset'
# Exception in processing frame 302: 'time_offset'
# Exception in processing frame 303: 'time_offset'
# Exception in processing frame 304: 'time_offset'
# Exception in processing frame 305: 'time_offset'
# Exception in processing frame 306: 'time_offset'
# Exception in processing frame 307: 'time_offset'
# Exception in processing frame 308: 'time_offset'
# Exception in processing frame 309: 'time_offset'
# Exception in processing frame 310: 'time_offset'
# Exception in processing frame 311: 'time_offset'
# Exception in processing frame 312: 'time_offset'
# Exception in processing frame 313: 'time_offset'
# Exception in processing frame 314: 'time_offset'
# Exception in processing frame 315: 'time_offset'
# Exception in processing frame 316: 'time_offset'
# Exception in processing frame 317: 'time_offset'
# Exception in processing frame 318: 'time_offset'
# Exception in processing frame 319: 'time_offset'
# Exception in processing frame 320: 'time_offset'
# Exception in processing frame 321: 'time_offset'
# Exception in processing frame 322: 'time_offset'
# Exception in processing frame 323: 'time_offset'
# Exception in processing frame 324: 'time_offset'
# Exception in processing frame 325: 'time_offset'
# Exception in processing frame 326: 'time_offset'
# Exception in processing frame 327: 'time_offset'
# Exception in processing frame 328: 'time_offset'
# Exception in processing frame 329: 'time_offset'
# Exception in processing frame 330: 'time_offset'
# Exception in processing frame 331: 'time_offset'
# Exception in processing frame 332: 'time_offset'
# Exception in processing frame 333: 'time_offset'
# Exception in processing frame 334: 'time_offset'
# Exception in processing frame 335: 'time_offset'
# Exception in processing frame 336: 'time_offset'
# Exception in processing frame 337: 'time_offset'
# Exception in processing frame 338: 'time_offset'
# Exception in processing frame 339: 'time_offset'
# Exception in processing frame 340: 'time_offset'
# Exception in processing frame 341: 'time_offset'
# Exception in processing frame 342: 'time_offset'
# Exception in processing frame 343: 'time_offset'
# Exception in processing frame 344: 'time_offset'
# Exception in processing frame 345: 'time_offset'
# Exception in processing frame 346: 'time_offset'
# Exception in processing frame 347: 'time_offset'
# Exception in processing frame 348: 'time_offset'
# Exception in processing frame 349: 'time_offset'
# Exception in processing frame 350: 'time_offset'
# Exception in processing frame 351: 'time_offset'
# Exception in processing frame 352: 'time_offset'
# Exception in processing frame 353: 'time_offset'
# Exception in processing frame 354: 'time_offset'
# Exception in processing frame 355: 'time_offset'
# Exception in processing frame 356: 'time_offset'
# Exception in processing frame 357: 'time_offset'
# Exception in processing frame 358: 'time_offset'
# Exception in processing frame 359: 'time_offset'
# Exception in processing frame 360: 'time_offset'
# Exception in processing frame 361: 'time_offset'
# Exception in processing frame 362: 'time_offset'
# Exception in processing frame 363: 'time_offset'
# Exception in processing frame 364: 'time_offset'
# Exception in processing frame 365: 'time_offset'
# Exception in processing frame 366: 'time_offset'
# Exception in processing frame 367: 'time_offset'
# Exception in processing frame 368: 'time_offset'
# Exception in processing frame 369: 'time_offset'
# Exception in processing frame 370: 'time_offset'
# Exception in processing frame 371: 'time_offset'
# Exception in processing frame 372: 'time_offset'
# Exception in processing frame 373: 'time_offset'
# Exception in processing frame 374: 'time_offset'
# Exception in processing frame 375: 'time_offset'
# Exception in processing frame 376: 'time_offset'
# Exception in processing frame 377: 'time_offset'
# Exception in processing frame 378: 'time_offset'
# Exception in processing frame 379: 'time_offset'
# Exception in processing frame 380: 'time_offset'
# Exception in processing frame 381: 'time_offset'
# Exception in processing frame 382: 'time_offset'
# Exception in processing frame 383: 'time_offset'
# Exception in processing frame 384: 'time_offset'
# Exception in processing frame 385: 'time_offset'
# Exception in processing frame 386: 'time_offset'
# Exception in processing frame 387: 'time_offset'
# Exception in processing frame 388: 'time_offset'
# Exception in processing frame 389: 'time_offset'
# Exception in processing frame 390: 'time_offset'
# Exception in processing frame 391: 'time_offset'
# Exception in processing frame 392: 'time_offset'
# Exception in processing frame 393: 'time_offset'
# Exception in processing frame 394: 'time_offset'
# Exception in processing frame 395: 'time_offset'
# Exception in processing frame 396: 'time_offset'
# Exception in processing frame 397: 'time_offset'
# Exception in processing frame 398: 'time_offset'
# Exception in processing frame 399: 'time_offset'
# Exception in processing frame 400: 'time_offset'
# Exception in processing frame 401: 'time_offset'
# Exception in processing frame 402: 'time_offset'
# Exception in processing frame 403: 'time_offset'
# Exception in processing frame 404: 'time_offset'
# Exception in processing frame 405: 'time_offset'
# Exception in processing frame 406: 'time_offset'
# Exception in processing frame 407: 'time_offset'
# Exception in processing frame 408: 'time_offset'
# Exception in processing frame 409: 'time_offset'
# Exception in processing frame 410: 'time_offset'
# Exception in processing frame 411: 'time_offset'
# Exception in processing frame 412: 'time_offset'
# Exception in processing frame 413: 'time_offset'
# Exception in processing frame 414: 'time_offset'
# Exception in processing frame 415: 'time_offset'
# Exception in processing frame 416: 'time_offset'
# Exception in processing frame 417: 'time_offset'
# Exception in processing frame 418: 'time_offset'
# Exception in processing frame 419: 'time_offset'
# Exception in processing frame 420: 'time_offset'
# Exception in processing frame 421: 'time_offset'
# Exception in processing frame 422: 'time_offset'
# Exception in processing frame 423: 'time_offset'
# Exception in processing frame 424: 'time_offset'
# Exception in processing frame 425: 'time_offset'
# Exception in processing frame 426: 'time_offset'
# Exception in processing frame 427: 'time_offset'
# Exception in processing frame 428: 'time_offset'
# Exception in processing frame 429: 'time_offset'
# Exception in processing frame 430: 'time_offset'
# Exception in processing frame 431: 'time_offset'
# Exception in processing frame 432: 'time_offset'
# Exception in processing frame 433: 'time_offset'
# Exception in processing frame 434: 'time_offset'
# Exception in processing frame 435: 'time_offset'
# Exception in processing frame 436: 'time_offset'
# Exception in processing frame 437: 'time_offset'
# Exception in processing frame 438: 'time_offset'
# Exception in processing frame 439: 'time_offset'
# Exception in processing frame 440: 'time_offset'
# Exception in processing frame 441: 'time_offset'
# Exception in processing frame 442: 'time_offset'
# Exception in processing frame 443: 'time_offset'
# Exception in processing frame 444: 'time_offset'
# Exception in processing frame 445: 'time_offset'
# Exception in processing frame 446: 'time_offset'
# Exception in processing frame 447: 'time_offset'
# Exception in processing frame 448: 'time_offset'
# Exception in processing frame 449: 'time_offset'
# Exception in processing frame 450: 'time_offset'
# Exception in processing frame 451: 'time_offset'
# Exception in processing frame 452: 'time_offset'
# Exception in processing frame 453: 'time_offset'
# Exception in processing frame 454: 'time_offset'
# Exception in processing frame 455: 'time_offset'
# Exception in processing frame 456: 'time_offset'
# Exception in processing frame 457: 'time_offset'
# Exception in processing frame 458: 'time_offset'
# Exception in processing frame 459: 'time_offset'
# Exception in processing frame 460: 'time_offset'
# Exception in processing frame 461: 'time_offset'
# Exception in processing frame 462: 'time_offset'
# Exception in processing frame 463: 'time_offset'
# Exception in processing frame 464: 'time_offset'
# Exception in processing frame 465: 'time_offset'
# Exception in processing frame 466: 'time_offset'
# Exception in processing frame 467: 'time_offset'
# Exception in processing frame 468: 'time_offset'
# Exception in processing frame 469: 'time_offset'
# Exception in processing frame 470: 'time_offset'
# Exception in processing frame 471: 'time_offset'
# Exception in processing frame 472: 'time_offset'
# Exception in processing frame 473: 'time_offset'
# Exception in processing frame 474: 'time_offset'
# Exception in processing frame 475: 'time_offset'
# Exception in processing frame 476: 'time_offset'
# Exception in processing frame 477: 'time_offset'
# Exception in processing frame 478: 'time_offset'
# Exception in processing frame 479: 'time_offset'
# Exception in processing frame 480: 'time_offset'
# Exception in processing frame 481: 'time_offset'
# Exception in processing frame 482: 'time_offset'
# Exception in processing frame 483: 'time_offset'
# Exception in processing frame 484: 'time_offset'
# Exception in processing frame 485: 'time_offset'
# Exception in processing frame 486: 'time_offset'
# Exception in processing frame 487: 'time_offset'
# Exception in processing frame 488: 'time_offset'
# Exception in processing frame 489: 'time_offset'
# Exception in processing frame 490: 'time_offset'
# Exception in processing frame 491: 'time_offset'
# Exception in processing frame 492: 'time_offset'
# Exception in processing frame 493: 'time_offset'
# Exception in processing frame 494: 'time_offset'
# Exception in processing frame 495: 'time_offset'
# Exception in processing frame 496: 'time_offset'
# Exception in processing frame 497: 'time_offset'
# Exception in processing frame 498: 'time_offset'
# Exception in processing frame 499: 'time_offset'
# Exception in processing frame 500: 'time_offset'
# Exception in processing frame 501: 'time_offset'
# Exception in processing frame 502: 'time_offset'
# Exception in processing frame 503: 'time_offset'
# Exception in processing frame 504: 'time_offset'
# Exception in processing frame 505: 'time_offset'
# Exception in processing frame 506: 'time_offset'
# Exception in processing frame 507: 'time_offset'
# Exception in processing frame 508: 'time_offset'
# Exception in processing frame 509: 'time_offset'
# Exception in processing frame 510: 'time_offset'
# Exception in processing frame 511: 'time_offset'
# Exception in processing frame 512: 'time_offset'
# Exception in processing frame 513: 'time_offset'
# Exception in processing frame 514: 'time_offset'
# Exception in processing frame 515: 'time_offset'
# Exception in processing frame 516: 'time_offset'
# Exception in processing frame 517: 'time_offset'
# Exception in processing frame 518: 'time_offset'
# Exception in processing frame 519: 'time_offset'
# Exception in processing frame 520: 'time_offset'
# Exception in processing frame 521: 'time_offset'
# Exception in processing frame 522: 'time_offset'
# Exception in processing frame 523: 'time_offset'
# Exception in processing frame 524: 'time_offset'
# Exception in processing frame 525: 'time_offset'
# Exception in processing frame 526: 'time_offset'
# Exception in processing frame 527: 'time_offset'
# Exception in processing frame 528: 'time_offset'
# Exception in processing frame 529: 'time_offset'
# Exception in processing frame 530: 'time_offset'
# Exception in processing frame 531: 'time_offset'
# Exception in processing frame 532: 'time_offset'
# Exception in processing frame 533: 'time_offset'
# Exception in processing frame 534: 'time_offset'
# Exception in processing frame 535: 'time_offset'
# Exception in processing frame 536: 'time_offset'
# Exception in processing frame 537: 'time_offset'
# Exception in processing frame 538: 'time_offset'
# Exception in processing frame 539: 'time_offset'
# Exception in processing frame 540: 'time_offset'
# Exception in processing frame 541: 'time_offset'
# Exception in processing frame 542: 'time_offset'
# Exception in processing frame 543: 'time_offset'
# Exception in processing frame 544: 'time_offset'
# Exception in processing frame 545: 'time_offset'
# Exception in processing frame 546: 'time_offset'
# Exception in processing frame 547: 'time_offset'
# Exception in processing frame 548: 'time_offset'
# Exception in processing frame 549: 'time_offset'
# Exception in processing frame 550: 'time_offset'
# Exception in processing frame 551: 'time_offset'
# Exception in processing frame 552: 'time_offset'
# Exception in processing frame 553: 'time_offset'
# Exception in processing frame 554: 'time_offset'
# Exception in processing frame 555: 'time_offset'
# Exception in processing frame 556: 'time_offset'
# Exception in processing frame 557: 'time_offset'
# Exception in processing frame 558: 'time_offset'
# Exception in processing frame 559: 'time_offset'
# Exception in processing frame 560: 'time_offset'
# Exception in processing frame 561: 'time_offset'
# Exception in processing frame 562: 'time_offset'
# Exception in processing frame 563: 'time_offset'
# Exception in processing frame 564: 'time_offset'
# Exception in processing frame 565: 'time_offset'
# Exception in processing frame 566: 'time_offset'
# Exception in processing frame 567: 'time_offset'
# Exception in processing frame 568: 'time_offset'
# Exception in processing frame 569: 'time_offset'
# Exception in processing frame 570: 'time_offset'
# Exception in processing frame 571: 'time_offset'
# Exception in processing frame 572: 'time_offset'
# Exception in processing frame 573: 'time_offset'
# Exception in processing frame 574: 'time_offset'
# Exception in processing frame 575: 'time_offset'
# Exception in processing frame 576: 'time_offset'
# Exception in processing frame 577: 'time_offset'
# Exception in processing frame 578: 'time_offset'
# Exception in processing frame 579: 'time_offset'
# Exception in processing frame 580: 'time_offset'
# Exception in processing frame 581: 'time_offset'
# Exception in processing frame 582: 'time_offset'
# Exception in processing frame 583: 'time_offset'
# Exception in processing frame 584: 'time_offset'
# Exception in processing frame 585: 'time_offset'
# Exception in processing frame 586: 'time_offset'
# Exception in processing frame 587: 'time_offset'
# Exception in processing frame 588: 'time_offset'
# Exception in processing frame 589: 'time_offset'
# Exception in processing frame 590: 'time_offset'
# Exception in processing frame 591: 'time_offset'
# Exception in processing frame 592: 'time_offset'
# Exception in processing frame 593: 'time_offset'
# Exception in processing frame 594: 'time_offset'
# Exception in processing frame 595: 'time_offset'
# Exception in processing frame 596: 'time_offset'
# Exception in processing frame 597: 'time_offset'
# Exception in processing frame 598: 'time_offset'
# Exception in processing frame 599: 'time_offset'
# Exception in processing frame 600: 'time_offset'
# Exception in processing frame 601: 'time_offset'
# Exception in processing frame 602: 'time_offset'
# Exception in processing frame 603: 'time_offset'
# Exception in processing frame 604: 'time_offset'
# Exception in processing frame 605: 'time_offset'
# Exception in processing frame 606: 'time_offset'
# Exception in processing frame 607: 'time_offset'
# Exception in processing frame 608: 'time_offset'
# Exception in processing frame 609: 'time_offset'
# Exception in processing frame 610: 'time_offset'
# Exception in processing frame 611: 'time_offset'
# Exception in processing frame 612: 'time_offset'
# Exception in processing frame 613: 'time_offset'
# Exception in processing frame 614: 'time_offset'
# Exception in processing frame 615: 'time_offset'
# Exception in processing frame 616: 'time_offset'
# Exception in processing frame 617: 'time_offset'
# Exception in processing frame 618: 'time_offset'
# Exception in processing frame 619: 'time_offset'
# Exception in processing frame 620: 'time_offset'
# Exception in processing frame 621: 'time_offset'
# Exception in processing frame 622: 'time_offset'
# Exception in processing frame 623: 'time_offset'
# Exception in processing frame 624: 'time_offset'
# Exception in processing frame 625: 'time_offset'
# Exception in processing frame 626: 'time_offset'
# Exception in processing frame 627: 'time_offset'
# Exception in processing frame 628: 'time_offset'
# Exception in processing frame 629: 'time_offset'
# Exception in processing frame 630: 'time_offset'
# Exception in processing frame 631: 'time_offset'
# Exception in processing frame 632: 'time_offset'
# Exception in processing frame 633: 'time_offset'
# Exception in processing frame 634: 'time_offset'
# Exception in processing frame 635: 'time_offset'
# Exception in processing frame 636: 'time_offset'
# Exception in processing frame 637: 'time_offset'
# Exception in processing frame 638: 'time_offset'
# Exception in processing frame 639: 'time_offset'
# Exception in processing frame 640: 'time_offset'
# Exception in processing frame 641: 'time_offset'
# Exception in processing frame 642: 'time_offset'
# Exception in processing frame 643: 'time_offset'
# Exception in processing frame 644: 'time_offset'
# Exception in processing frame 645: 'time_offset'
# Exception in processing frame 646: 'time_offset'
# Exception in processing frame 647: 'time_offset'
# Exception in processing frame 648: 'time_offset'
# Exception in processing frame 649: 'time_offset'
# Exception in processing frame 650: 'time_offset'
# Exception in processing frame 651: 'time_offset'
# Exception in processing frame 652: 'time_offset'
# Exception in processing frame 653: 'time_offset'
# Exception in processing frame 654: 'time_offset'
# Exception in processing frame 655: 'time_offset'
# Exception in processing frame 656: 'time_offset'
# Exception in processing frame 657: 'time_offset'
# Exception in processing frame 658: 'time_offset'
# Exception in processing frame 659: 'time_offset'
# Exception in processing frame 660: 'time_offset'
# Exception in processing frame 661: 'time_offset'
# Exception in processing frame 662: 'time_offset'
# Exception in processing frame 663: 'time_offset'
# Exception in processing frame 664: 'time_offset'
# Exception in processing frame 665: 'time_offset'
# Exception in processing frame 666: 'time_offset'
# Exception in processing frame 667: 'time_offset'
# Exception in processing frame 668: 'time_offset'
# Exception in processing frame 669: 'time_offset'
# Exception in processing frame 670: 'time_offset'
# Exception in processing frame 671: 'time_offset'
# Exception in processing frame 672: 'time_offset'
# Exception in processing frame 673: 'time_offset'
# Exception in processing frame 674: 'time_offset'
# Exception in processing frame 675: 'time_offset'
# Exception in processing frame 676: 'time_offset'
# Exception in processing frame 677: 'time_offset'
# Exception in processing frame 678: 'time_offset'
# Exception in processing frame 679: 'time_offset'
